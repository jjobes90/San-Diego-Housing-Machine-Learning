# %%
cd
# Out:
# /Users/jjobes

# %%
cd /Users/jjobes/Desktop/Real_Estate
# Out:
# /Users/jjobes/Desktop/Real_Estate

# %%
ls
# Out:
# EDA_df.csv                   Spreadsheet35).csv
# Real_Estate_EDA.ipynb        Spreadsheet36).csv
# Real_Estate_Wrangling.ipynb  Spreadsheet37).csv
# Sheet1.csv                   Spreadsheet38).csv
# Sheet12.csv                  Spreadsheet39).csv
# Sheet13.csv                  Spreadsheet40).csv
# Sheet14.csv                  Spreadsheet41).csv
# Sheet15.csv                  Spreadsheet42).csv
# Sheet16.csv                  Spreadsheet43).csv
# Sheet17.csv                  Spreadsheet44).csv
# Sheet18.csv                  Spreadsheet45).csv
# Spreadsheet10).csv           Spreadsheet46).csv
# Spreadsheet11).csv           Spreadsheet47).csv
# Spreadsheet12).csv           Spreadsheet48).csv
# Spreadsheet13).csv           Spreadsheet49).csv
# Spreadsheet14).csv           Spreadsheet50).csv
# Spreadsheet15).csv           Spreadsheet52).csv
# Spreadsheet17).csv           Spreadsheet53).csv
# Spreadsheet18).csv           Spreadsheet54).csv
# Spreadsheet19).csv           Spreadsheet55).csv
# ...

# %%
import pandas as pd

cleaned_df = pd.read_csv('cleaned_df.csv')

# %%
print(cleaned_df.shape)

cleaned_df.head()
# Out:
# (94852, 19)
#    Zip_Code  Year_Built  Total_Stories  Total_Building_Stories  \
# 0     92118      1987.0            3.0                     0.0
# 1     92118      1928.0            1.0                     0.0
# 2     92118      1993.0            3.0                     0.0
# 3     92118      1932.0            1.0                     0.0
# 4     92118      1985.0            2.0                     2.0
#
#    Total_Parking_Spaces  Fireplaces  Total_Bedrooms  Total_Bathrooms Style  \
# 0                   0.0         0.0             2.0              3.0   ATT
# 1                   3.0         1.0             2.0              1.0   DET
# 2                   0.0         0.0             3.0              3.0   ATT
# 3                   1.0         0.0             2.0              1.0   DET
# 4                   2.0         1.0             2.0              3.0   ATT
#
#           Full Address Community  EstSF    Lst Date  Sold Price  \
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94852 entries, 0 to 94851
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Zip_Code                94852 non-null  int64
#  1   Year_Built              94852 non-null  float64
#  2   Total_Stories           94852 non-null  float64
#  3   Total_Building_Stories  94852 non-null  float64
#  4   Total_Parking_Spaces    94852 non-null  float64
#  5   Fireplaces              94852 non-null  float64
#  6   Total_Bedrooms          94852 non-null  float64
#  7   Total_Bathrooms         94852 non-null  float64
#  8   Style                   94852 non-null  object
#  9   Full Address            94852 non-null  object
#  10  Community               94852 non-null  object
#  11  EstSF                   94852 non-null  int64
#  12  Lst Date                94852 non-null  object
#  13  Sold Price              94852 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Total_Bedrooms', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Total_Bathrooms', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Style', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Zip_Code', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Class', y="Sold Price", data=cleaned_df)

# %%
del cleaned_df['Class']

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Levels', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Community', y="Sold Price", data=cleaned_df)

# %%
len(cleaned_df['Community'].unique())
# Out:
# 96

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.scatterplot(x='Year_Built', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.scatterplot(x='Lst Date', y="Sold Price", data=cleaned_df)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.boxplot(x='Fireplaces', y="Sold Price", data=cleaned_df)

# %%
cleaned_df.to_csv('EDA_df.csv', index = False, header=True)
